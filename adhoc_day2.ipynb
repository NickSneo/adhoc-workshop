# %% [markdown]
# <a href="https://colab.research.google.com/github/NickSneo/adhoc-workshop/blob/master/adhoc_day2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from bs4 import BeautifulSoup
import requests 
import time

# %%
#now taking corona live data
url="https://www.worldometers.info/coronavirus/"
htmlpage = requests.get(url)

# %%
purehtmlpage = htmlpage.content
soup = BeautifulSoup(purehtmlpage,'html5lib')

# %%
print(type(soup))
tb = soup.find_all('table',class_ = "table table-bordered table-hover main_table_countries")

for trr in tb[0].find_all('tr'):
  for rows in trr.find_all('th'):
    print(rows.text)
# Out:
# <class 'bs4.BeautifulSoup'>
# Country,Other
# TotalCases
# NewCases
# TotalDeaths
# NewDeaths
# TotalRecovered
# ActiveCases
# Serious,Critical
# Tot Cases/1M pop
# Tot Deaths/1M pop

# %%
#now scraping data fpr eah row with normal vountry data
for trr in tb[0].find_all('tr'):
  for rows in trr.find_all ('td'):
    print(rows.text)
# Out:
# China
# 81,340
# +55
# 3,292
# +5
# 74,588
# 3,460
# 1,034
# 57
# 2
# USA
# 100,514
# +15,079
# 1,546
# +251
# 2,465
# 96,503
# 2,463
# 304
# 5
# Italy
# 86,498
# +5,909
# 9,134
# +919
# 10,950
# 66,414
# 3,732
# 1,431
# 151
# Spain
# 64,285
# +6,499
# 4,940
# +575
# 9,357
# 49,988
# 4,165
# 1,375
# 106
# Germany
# 50,871
# +6,933
# 342
# +75
# 6,658
# 43,871
# 23
# 607
# 4
# France
# 32,964
# +3,809
# 1,995
# +299
# 5,700
# 25,269
# 3,787
# 505
# 31
# Iran
# 32,332
# +2,926
# 2,378
# +144
# 11,133
# 18,821
# 2,893
# 385
# 28
# UK
# 14,543
# +2,885
# 759
# +181
# 135
# 13,649
# 163
# 214
# 11
# Switzerland
# 12,928
# +1,117
# 231
# +39
# 1,530
# 11,167
# 203
# 1,494
# 27
# S. Korea
# 9,332
# +91
# 139
# +8
# 4,528
# 4,665
# 59
# 182
# 3
# Netherlands
# 8,603
# +1,172
# 546
# +112
# 3
# 8,054
# 761
# 502
# 32
# Austria
# 7,657
# +748
# 58
# +9
# 225
# 7,374
# 128
# 850
# 6
# Belgium
# 7,284
# +1,049
# 289
# +69
# 858
# 6,137
# 690
# 628
# 25
# Turkey
# 5,698
# +2,069
# 92
# +17
# 42
# ...
